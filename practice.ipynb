# %%
l1=[5,[10,15,[20,25,[30,35],40],45],50]
l1[1][0:3]
# Out:
# [10, 15, [20, 25, [30, 35], 40]]

# %%
l=[10,20,60,30,20,40,30,60,70,80]
l1=[]
l2=[]
for i in l:
  if i not in l1:
    l1.append(i)
  elif i not in l2:
    l2.append(i)   
print(l2)
# Out:
# [20, 30, 60]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("/content/Car details v3.csv")

# %%
data.head(2)
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
#
#   seller_type transmission         owner     mileage   engine   max_power  \
# 0  Individual       Manual   First Owner   23.4 kmpl  1248 CC      74 bhp
# 1  Individual       Manual  Second Owner  21.14 kmpl  1498 CC  103.52 bhp
#
#                 torque  seats
# 0       190Nm@ 2000rpm    5.0
# 1  250Nm@ 1500-2500rpm    5.0

# %%
data['fuel']=data['fuel'].apply({"Diesel":0,'Petrol':1}.get)
data['seller_type']=data['seller_type'].apply({'individual':0}.get)

# %%
data.head(2)
# Out:
#                            name  year  selling_price  km_driven  fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  None
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  None
#
#   seller_type transmission         owner     mileage   engine   max_power  \
# 0        None       Manual   First Owner   23.4 kmpl  1248 CC      74 bhp
# 1        None       Manual  Second Owner  21.14 kmpl  1498 CC  103.52 bhp
#
#                 torque  seats
# 0       190Nm@ 2000rpm    5.0
# 1  250Nm@ 1500-2500rpm    5.0

# %%
data.drop(['torque'],axis=1)
# Out:
#                               name  year  selling_price  km_driven    fuel  \
# 0           Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1     Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2         Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3        Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4           Maruti Swift VXI BSIII  2007         130000     120000  Petrol
# ...                            ...   ...            ...        ...     ...
# 8123             Hyundai i20 Magna  2013         320000     110000  Petrol
# 8124         Hyundai Verna CRDi SX  2007         135000     119000  Diesel
# 8125        Maruti Swift Dzire ZDi  2009         382000     120000  Diesel
# 8126               Tata Indigo CR4  2013         290000      25000  Diesel
# 8127               Tata Indigo CR4  2013         290000      25000  Diesel
#
# ...

# %%
data.tail()
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 296     city  2016           9.50           11.6       33988    Diesel
# 297     brio  2015           4.00            5.9       60000    Petrol
# 298     city  2009           3.35           11.0       87934    Petrol
# 299     city  2017          11.50           12.5        9000    Diesel
# 300     brio  2016           5.30            5.9        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 296      Dealer       Manual      0
# 297      Dealer       Manual      0
# 298      Dealer       Manual      0
# 299      Dealer       Manual      0
# 300      Dealer       Manual      0

# %%
sns.pairplot(x_vars=['Selling_Price','Present_Price'],y_vars='Fuel_Type',data=data)
